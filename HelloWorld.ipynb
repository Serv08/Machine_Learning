# %%
# Hello World
print("Hello World")

# %%
# Linear Regression

import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

data = pd.read_csv("student-mat.csv", sep=';')
# print(data.head())

data = data[["G1", 'G2', 'G3', 'studytime', 'failures', 'absences']]    # Data chosen should be integer
# print(data.head())

# LABELS
predict = "G3"      # G3 is the final grade we want to predict, thus labeling G3 as 'predict'

x = np.array(data.drop(columns='G3'))
# x = np.array(data.drop([predict], 1))
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.2) 
# x_train and y_train are sections while x_test and y_test will test the accuracy of the data
# model_selection randomizes arrays and matrices into subsets for training and testing of data
# train_test_split splits the data into train and test sets


linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)        # .fit for best fit line
acc = linear.score(x_test, y_test)  # .score test the accuracy
print('Accurancy: \t', round(acc*100,2),'%')

print('Coefficients: \t', linear.coef_)     # B (coefficient)
print('Intercept: \t', linear.intercept_)   # Y-intercept

predictions = linear.predict(x_test)
print('\nPredictions\tData\t\t\tActual Grade')
for x in range(len(predictions)):
    print(round(predictions[x],7), x_test[x], y_test[x], sep='\t')
# Out:
# Accurancy: 	 84.01 %
# Coefficients: 	 [ 0.18188191  0.95069936 -0.13303778 -0.27311403  0.04281416]
# Intercept: 	 -1.687047522913005
#
# Predictions	Data			Actual Grade
# 12.7598082	[12 13  2  0  4]	13
# 10.5908992	[11 11  2  0  2]	10
# 13.4490273	[12 14  3  0  1]	15
# 12.8560618	[13 13  2  0  2]	13
# 8.1438548	[8 9 2 0 2]	10
# 11.2321031	[12 11  1  1 16]	12
# 9.6769841	[10 10  1  0  4]	10
# 10.4090173	[10 11  2  0  2]	11
# 15.4697676	[16 15  3  0  9]	16
# 12.3059104	[14 12  1  0  4]	11
# 9.0839289	[ 7 10  2  0  6]	10
# 7.4712909	[10  8  2  0  0]	9
# 8.2294831	[8 9 2 0 4]	10
# 4.9279929	[6 6 2 0 2]	6
# -1.7300178	[5 0 1 3 0]	0
# 8.1912642	[8 9 1 0 0]	8
# 11.9546093	[14 11  1  0 18]	13
# 19.4711022	[19 19  4  0  4]	20
# 4.2235532	[ 5  5  2  0 12]	5
# 4.6241012	[ 6  5  1  0 14]	5
# 9.5439463	[10 10  2  0  4]	10
# 12.0504602	[15 12  3  0  0]	14
# 9.1801825	[ 8 10  2  0  4]	10
# 16.1529567	[15 16  3  0  7]	15
# 14.8537141	[14 15  2  0  0]	15
# 11.9421466	[12 12  1  0  4]	13
# 12.2155971	[10 13  4  0  6]	13
# 5.1258346	[ 6  6  2  1 13]	8
# 8.898976	[11  9  3  0 10]	10
# 8.4219903	[10  9  2  0  0]	9
# 7.7175506	[ 9  8  2  0 10]	8
# 7.7433068	[7 9 3 0 0]	8
# 7.725643	[6 9 1 1 4]	8
# 14.5267345	[11 15  1  0  2]	15
# 11.6330523	[10  9  2  0 75]	9
# 15.5645865	[16 15  1  0  5]	16
# 9.2764361	[ 9 10  2  0  2]	9
# 10.1415071	[ 9 11  2  0  0]	12
# 13.5195247	[15 13  2  0  9]	15
# 8.1559147	[10  9  4  0  0]	0
# 8.411365	[9 9 2 0 4]	10
# 11.6322484	[13 12  2  1  2]	12
# 8.4208921	[ 7 10  3  1  0]	10
# 11.4145908	[12 12  4  0  1]	12
# 10.5052709	[11 11  2  0  0]	10
# 12.9034713	[13 13  1  0  0]	12
# 7.8763445	[7 9 2 0 0]	8
# 12.8409309	[16 12  1  0  8]	13
# 13.7472917	[11 14  1  0  6]	14
# 12.8560618	[13 13  2  0  2]	13
# -0.3161859	[9 0 2 0 0]	0
# 18.7008501	[19 18  2  0  2]	18
# 9.5927904	[11 10  3  0  4]	10
# 3.4784749	[6 5 1 2 0]	0
# 7.1075271	[8 8 2 0 0]	9
# 5.4523881	[ 7  6  2  0 10]	6
# 15.6884337	[16 15  2  0 11]	15
# 15.7694667	[16 15  3  0 16]	15
# 9.9596252	[ 8 11  2  0  0]	11
# 16.2538056	[16 16  2  0  2]	17
# 7.016295	[9 8 2 1 0]	0
# 3.6673953	[7 5 3 1 0]	0
# 9.2658108	[ 8 10  2  0  6]	10
# 15.9388859	[15 16  3  0  2]	18
# 5.7874601	[7 7 2 1 2]	7
# 10.5006756	[11 11  3  0  3]	11
# 6.8599897	[9 8 1 3 6]	10
# 12.397479	[11 13  4  0  6]	14
# 12.2372504	[12 12  2  0 14]	12
# 9.0359371	[10 10  3  2  8]	10
# 13.7211328	[13 14  2  0  0]	15
# 12.7704335	[13 13  2  0  0]	12
# 18.4241492	[18 18  4  0  6]	18
# 12.5885516	[12 13  2  0  0]	13
# 9.6557335	[ 8 10  1  0 12]	10
# 6.9218788	[ 9  7  2  1 20]	8
# 11.0433623	[ 8 12  1  0  0]	12
# 9.2032704	[11  9  2  0 14]	9
# 12.1754493	[13 11  3  1 40]	11
