# %%
# Hello World
print("Hello World")

# %%
# Linear Regression

import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression

data = pd.read_csv("student-mat.csv", sep=';')
# print(data.head())

data = data[["G1", 'G2', 'G3', 'studytime', 'failures', 'absences']]    # Data chosen should be integer
# print(data.head())

# LABELS
predict = "G3"      # G3 is the final grade we want to predict, thus labeling G3 as 'predict'

x = np.array(data.drop(columns='G3'))       # data inputs
# x = np.array(data.drop([predict], 1))
y = np.array(data[predict])                 # output

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.2)      # creates 4 outputs data set
# x_train and y_train are the data that will be used to train the program while x_test and y_test will test the accuracy of the program
# model_selection randomizes arrays and matrices into subsets for training and testing of data
# train_test_split splits the data into train and test sets
# print(f"x_train:\t{x_train}\tx_test:\t{x_test}\ny_train:\t{y_train}\ty_test:\t{y_test}")

linear = LinearRegression()
# sklearn.linear_model.LinearRegression()

linear.fit(x_train, y_train)        # .fit for best fit line
acc = linear.score(x_test, y_test)  # .score test the accuracy
print('Accurancy: \t', round(acc*100,2),'%')

print('Coefficients: \t', linear.coef_)     # B (coefficient)
print('Intercept: \t', linear.intercept_)   # Y-intercept

predictions = linear.predict(x_test)
print('\nPredictions\tData\t\t\tActual Grade')
for x in range(len(predictions)):
    print(round(predictions[x],7), x_test[x], y_test[x], sep='\t')
# Out:
# Accurancy: 	 84.27 %
# Coefficients: 	 [ 0.1541655   0.96436699 -0.21253957 -0.23243182  0.04219612]
# Intercept: 	 -1.2706868611837248
#
# Predictions	Data			Actual Grade
# 12.3740828	[14 12  1  0  3]	12
# 18.2659164	[18 18  4  0  6]	18
# 11.689901	[10  9  2  0 75]	9
# 16.3549193	[17 16  2  0  0]	16
# 7.4013861	[8 8 1 1 4]	8
# 12.6326168	[13 13  3  0  0]	13
# 19.4306335	[18 18  1  1 24]	18
# 14.9864299	[13 15  1  0  0]	15
# 3.8186301	[6 5 2 1 0]	0
# 15.0822213	[15 15  2  0  0]	15
# 8.3012531	[8 9 2 0 2]	8
# 9.5118806	[ 9  9  1  0 22]	9
# 12.5888617	[13 13  4  0  4]	12
# 11.7104459	[13 12  3  0  1]	12
# 9.4344046	[ 8 10  2  0  6]	10
# 10.6227104	[10 11  2  0  4]	9
# -0.2124851	[11  0  3  0  0]	0
# 9.0270624	[ 7 10  2  0  0]	11
# 11.0852069	[13 11  2  0  4]	11
# 7.0659725	[9 8 4 0 2]	8
# 11.3225014	[ 8 12  1  0  0]	12
# 9.2916383	[ 9 10  3  0  4]	10
# 9.5999693	[11 10  3  0  4]	10
# 8.0265412	[10  8  1  0  6]	11
# 10.9164224	[13 11  2  0  0]	10
# -0.5582334	[6 0 1 0 0]	0
# 13.9199338	[14 14  3  0  4]	14
# 7.2524939	[8 8 2 0 0]	0
# 11.9214265	[13 12  3  0  6]	12
# 5.9284004	[8 7 2 3 8]	8
# 12.0426576	[14 11  1  0 18]	13
# 5.1497022	[7 6 1 1 0]	0
# 6.8229942	[ 7  8  2  3 10]	10
# 5.1144402	[5 6 2 0 6]	6
# 11.9798006	[12 12  2  0  6]	12
# 5.5908315	[8 7 2 3 0]	0
# 8.3856454	[8 9 2 0 4]	10
# 12.4569161	[14 12  2  0 10]	11
# 8.3856454	[8 9 2 0 4]	10
# 13.5494304	[14 13  1  0  8]	13
# 12.7639839	[10 13  1  0  4]	14
# 8.5398109	[9 9 2 0 4]	10
# 10.5221402	[11 11  3  0  3]	11
# 10.6924836	[11 11  2  0  2]	11
# 15.0822213	[15 15  2  0  0]	15
# 15.1666136	[15 15  2  0  2]	16
# 11.7849979	[11 12  1  0  0]	10
# 13.9636888	[14 14  2  0  0]	14
# 7.2026574	[10  8  1  3  3]	7
# 7.5608249	[10  8  2  0  0]	9
# 12.2767324	[12 12  1  0  8]	12
# 11.8110161	[12 12  2  0  2]	11
# 15.7718764	[17 15  1  0  4]	16
# 15.3207791	[16 15  2  0  2]	15
# 11.2264142	[12 11  2  0 11]	11
# 11.7152247	[10 12  1  0  2]	12
# 12.8933944	[16 12  1  0  8]	13
# 14.8322644	[12 15  1  0  0]	15
# 5.9797959	[6 7 2 0 0]	0
# 6.0832901	[ 8  6  2  0 18]	7
# 10.7340092	[ 9  9  2  0 56]	8
# 3.5663061	[6 5 1 3 0]	0
# 12.9388943	[11 13  1  1 10]	13
# 18.9879273	[18 18  1  0  8]	18
# 18.6763765	[19 18  2  0  2]	18
# 11.3546455	[10 12  2  1  4]	12
# 13.2817365	[12 13  2  0 14]	12
# 12.3649229	[11 13  4  0  6]	14
# 9.6583434	[10 10  2  0  4]	10
# 7.8501558	[7 9 3 0 0]	8
# 9.4895589	[10 10  2  0  0]	10
# -1.4096944	[5 0 1 3 0]	0
# 4.0311697	[6 5 1 1 0]	0
# 3.6060905	[6 5 3 1 0]	0
# 10.5383181	[10 11  2  0  2]	11
# 13.7381911	[12 14  3  0  7]	14
# 10.171613	[ 9 11  3  0  2]	11
# 8.6242031	[9 9 2 0 6]	10
# 9.5041779	[ 9 10  2  0  4]	10
